# %%
import sys
sys.path.append('/home/jovyan/workspace')

# %%
import modelscripts
import planetengine

# %%
system = modelscripts.arrhenius.build(res = 16, Ra = 1e4, f = 1., eta0 = 1.)

# %%
planetengine.initials.apply(
    {'temperatureField': planetengine.initials.sinusoidal.IC(freq = 1.)},
    system,
    )

# %%
for i in range(100):
    system.iterate()

# %%
planetengine.quickShow(system.temperatureField)
# Out:
# Fitted 1 variables to the figure.
# <img src='data:image/png;base64,...'>

# %%
surfGradInt = planetengine.analysis.Analyse.StandardIntegral(
    system.temperatureField,
    gradient = 'rad',
    surface = 'outer',
    )
# Out:
# Building integral...
# Integral built.

# %%
surfGradInt.evaluate()
# Out:
# 3.9045266050032561

# %%
bucketInt = planetengine.analysis.Analyse.StandardIntegral(
    system.temperatureField,
    gradient = 'rad',
    surface = 'outer',
    bucket = ('min', 2.),
    )
# Out:
# Building integral...
# Integral built.

# %%
bucketInt.evaluate()
# Out:
# 0.20486111111404076
