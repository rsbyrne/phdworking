# %%
import sys
sys.path.append('/workspace/user_data')

# %%
import modelscripts
import planetengine

# %%
from underworld import function as fn

# %%
initial = {
    'temperatureField': planetengine.initials.sinusoidal.IC(),
    }

# %%
system = modelscripts.isovisc_systemscript.build(res = 32)

# %%
obsVars = {
    'temperature': system.temperatureField,
    'velocity': system.velocityField,
#     'viscosity': system.viscosityFn,
#     'stressRMS': fn.math.sqrt(
#         fn.math.dot(
#             system.viscosityFn * system.velocityField,
#             system.viscosityFn * system.velocityField
#             )
#         )
    }
observer = planetengine.observer.build(
    obsVars,
    system.step,
    system.modeltime
    )
# Out:
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Building integral...
# Integral built.
# Fitted 2 variables to the figure.

# %%
outputPath = '/workspace/user_data/tests/MS98X_newPE'

# %%
model = planetengine.frame.make_frame(
    system,
    observer,
    initial,
    outputPath
    )
# Out:
# Making a new frame...
# Making stamps...
# Stamps made.
# Building frame...
# Making stamps...
# Stamps made.
# Loading interior frames...
# Loaded 0 interior frames.
# Initialising...
# Initialisation complete!
# Frame built!
# Frame made.

# %%
model.report()
# Out:
# Reporting...
# modeltime
# 0.0E+00
# step
# 0
# temperature_angGrad_innerInt
# -0.00
# temperature_angGrad_outerInt
# 0.00
# temperature_angGrad_volumeInt
# 0.25
# temperature_innerInt
# 1.00
# temperature_outerInt
# 0.00
# temperature_radGrad_innerInt
# -1.00
# temperature_radGrad_outerInt
# -1.00
# temperature_radGrad_volumeInt
# -1.00
# temperature_volumeInt
# 0.45
# velocity_angComp_angGrad_innerInt
# -1665.42
# velocity_angComp_angGrad_outerInt
# -1648.79
# velocity_angComp_angGrad_volumeInt
# -1285.91
# velocity_angComp_innerInt
# 27999.13
# velocity_angComp_outerInt
# -35259.62
# velocity_angComp_radGrad_innerInt
# 46436.98
# velocity_angComp_radGrad_outerInt
# -78556.72
# velocity_angComp_radGrad_volumeInt
# -65885.75
# velocity_angComp_volumeInt
# -780.22
# velocity_angGrad_innerInt
# -3883.64
# velocity_angGrad_outerInt
# -1408.02
# velocity_angGrad_volumeInt
# -4010.44
# velocity_innerInt
# 28169.75
# velocity_outerInt
# 35689.01
# velocity_radComp_angGrad_innerInt
# 5805.74
# velocity_radComp_angGrad_outerInt
# 2149.61
# velocity_radComp_angGrad_volumeInt
# 64744.70
# velocity_radComp_innerInt
# -2205.38
# velocity_radComp_outerInt
# -4084.05
# velocity_radComp_radGrad_innerInt
# 34449.65
# velocity_radComp_radGrad_outerInt
# -63741.15
# velocity_radComp_radGrad_volumeInt
# -2437.89
# velocity_radComp_volumeInt
# -182.68
# velocity_radGrad_innerInt
# 62885.61
# velocity_radGrad_outerInt
# 70127.92
# velocity_radGrad_volumeInt
# 3428.61
# velocity_volumeInt
# 33775.24
# <img src='data:image/png;base64,...'>
# Reporting complete!

# %%
model.iterate()

# %%
model.report()

# %%
model.go(10)

# %%
model.report()

# %%
model.checkpoint()
