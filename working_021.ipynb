# %%
import sys
sys.path.append('..')

# %%
import planetengine
import modelscripts

# %%
initial = {
    'temperatureField': planetengine.initials.sinusoidal.IC(),
    'materialVar': planetengine.initials.extents.IC(
        (1, planetengine.shapes.trapezoid(
            thickness = 0.025,
            longwidth = 1.,
            lengthRatio = 1.
            ))
        )
    }

# %%
model = planetengine.frame.make_frame(
    modelscripts.MS98X_systemscript.build(aspect = 3., res = 64, Ra = 1e4),
    modelscripts.MS98X_observerscript.build(),
    initial
    )
# Out:
# Making a new frame...
# Making stamps...
# Stamps made.
# Building frame...
# Making stamps...
# Stamps made.
# Doing stuff with the observer...
# Observer stuff complete.
# Initialising...
# Initialisation complete!
# Frame built!
# Frame made.

# %%
model.report()
# Out:
# Reporting...
# Analysing...
# Analysis complete!
# avTemp 0.57
# avVisc 6.7E+03
# modeltime 0.0E+00
# Nu 1.1
# step 0
# surfVRMS 0.02
# VRMS 0.12
# yielding 0%
# fig
# <img src='data:image/png;base64,...'>
# Reporting complete!
