# %%
import math
import random

# %%
with open('../planetengine/words_alpha.txt', 'r') as file:
    wordlist = list(set(file.read().split('\n')))

# %%
wordlist
# Out:
# ['cippi',
#  'shanteys',
#  'barraged',
#  'disagreeable',
#  'shopful',
#  'sesquitertial',
#  'dunne',
#  'flexographically',
#  'windowpane',
#  'inumbrate',
#  'infumate',
#  'cottoned',
#  'preplaced',
#  'rockish',
#  'writeable',
#  'minimizing',
#  'taistrel',
#  'starosti',
#  'automobility',
#  'timalia',
#  'preenable',
#  'feued',
#  'pullmanize',
#  'dauntlessly',
#  'pleiad',
#  'nonspeaker',
#  'electrowinning',
#  'ballahou',
#  'zincification',
#  'remeasure',
#  'necromorphous',
#  'promenaders',
#  'permutableness',
#  'uromeric',
#  'nakhlite',
#  'outplease',
#  'neuroplasty',
#  'encarnadine',
#  'galvanotherapy',
#  'fogramity',
#  'haemamoeba',
#  'porulous',
#  'unsinewed',
#  'assemblies',
#  'esmeraldan',
#  'regald',
#  'electrotechnology',
#  'accelerated',
#  'inflammatory',
#  'hoofed',
#  'lusus',
#  'perp',
#  'epispadiac',
#  'undevisable',
#  'entrees',
#  'governments',
#  'daughters',
#  'receptacles',
#  'agents',
#  'unhallows',
#  'colazione',
#  'hectometer',
#  'muncupate',
#  'preact',
#  'sicklebill',
#  'sneerer',
#  'upway',
#  'vegetomineral',
#  'zygapophysis',
#  'statant',
#  'oropharyngeal',
#  'semisocial',
#  'unvigorously',
#  'jeer',
#  'paraphrastically',
#  'unmechanic',
#  'greenier',
#  'cartaceous',
#  'oilseeds',
#  'laryngoplasty',
#  'diglyphic',
#  'indebted',
#  'equalisation',
#  'manuscription',
#  'underpressure',
#  'binnacles',
#  'paedotrophist',
#  'provisor',
#  'circumspection',
#  'acetbromamide',
#  'awfu',
#  'laicizer',
#  'accessibility',
#  'chammied',
#  'gassendist',
#  'antennata',
#  'knappers',
#  'activations',
#  'landshark',
#  'granes',
#  'outdespatch',
#  'caciques',
#  'soapsuddy',
#  'revendication',
#  'emeus',
#  'womanizers',
#  'mir',
#  'madreporacean',
#  'trullan',
#  'repatriation',
#  'stammrel',
#  'hardiest',
#  'morlop',
#  'sulfuration',
#  'pettishly',
#  'comminuted',
#  'motorcycled',
#  'cromwell',
#  'monolater',
#  'bobadilian',
#  'protohistorian',
#  'seathe',
#  'championlike',
#  'sixthly',
#  'albarellos',
#  'bacteriostatically',
#  'indologenous',
#  'typifiers',
#  'poh',
#  'orthoepy',
#  'plaided',
#  'dialonian',
#  'proturan',
#  'corselet',
#  'cytosome',
#  'ascenseur',
#  'conservatism',
#  'rectilinearness',
#  'riggal',
#  'sniggled',
#  'trimolecular',
#  'weenong',
#  'structurely',
#  'pelasgic',
#  'dements',
#  'tormentous',
#  'perimetritis',
#  'replotment',
#  'bloodguilty',
#  'photoma',
#  'sneds',
#  'detractory',
#  'czarowitz',
#  'infraprotein',
#  'ultrafrivolous',
#  'outfieldsman',
#  'extraditions',
#  'lucigen',
#  'herbager',
#  'neoneds',
#  'rocketing',
#  'olivilin',
#  'sheugh',
#  'asianism',
#  'lappet',
#  'aneretic',
#  'nonfidelity',
#  'suicidally',
#  'pinafore',
#  'bangs',
#  'loverly',
#  'spulyiement',
#  'rosaceae',
#  'sternway',
#  'inkers',
#  'tuchunism',
#  'laker',
#  'elateroid',
#  'upperhandism',
#  'fbi',
#  'hasheesh',
#  'opals',
#  'alveolocondylean',
#  'submediant',
#  'stedman',
#  'rickstand',
#  'electrotechnic',
#  'sutorian',
#  'capsuliform',
#  'demihigh',
#  'dispersedelement',
#  'panopticon',
#  'athetosic',
#  'furnariides',
#  'cambism',
#  'antenniform',
#  'overstep',
#  'stockiest',
#  'jerque',
#  'magnetometry',
#  'labeller',
#  'runsy',
#  'burstiness',
#  'insanitation',
#  'xanthogenate',
#  'chummiest',
#  'ascariasis',
#  'ulceration',
#  'gluneamie',
#  'indentation',
#  'parols',
#  'neorealism',
#  'monocrotism',
#  'knicker',
#  'radiolocators',
#  'galeopsis',
#  'rheophilic',
#  'tincted',
#  'orb',
#  'actiniarian',
#  'climes',
#  'dhoty',
#  'vitals',
#  'telesthetic',
#  'hagrid',
#  'plicative',
#  'rib',
#  'tokening',
#  'aluminous',
#  'reincarnadine',
#  'aerialist',
#  'pedocal',
#  'brotocrystal',
#  'honorands',
#  'amoebocyte',
#  'marvelousness',
#  'hault',
#  'thereupon',
#  'hyperacute',
#  'culvers',
#  'pencatite',
#  'procidence',
#  'chaplanry',
#  'tufaceous',
#  'circumlocutionist',
#  'ambiguously',
#  'camelry',
#  'ani',
#  'innuit',
#  'sirens',
#  'torrifying',
#  'gushingness',
#  'jockettes',
#  'passingness',
#  'deltohedron',
#  'drifted',
#  'rigadoons',
#  'tyrr',
#  'annexes',
#  'strategy',
#  'sargassum',
#  'catechistic',
#  'cardboard',
#  'antepagments',
#  'bartends',
#  'caudices',
#  'forecourse',
#  'swaddles',
#  'darbies',
#  'preemies',
#  'trompillo',
#  'aeromotor',
#  'ceratoduses',
#  'polladz',
#  'nontruth',
#  'villenage',
#  'nonresidental',
#  'kinetographic',
#  'cosmographically',
#  'assayers',
#  'propositions',
#  'gowland',
#  'cuckoldize',
#  'listeriases',
#  'ferrugination',
#  'didelphine',
#  'presoaked',
#  'telotremata',
#  'pupoid',
#  'thecium',
#  'hexamerous',
#  'tzaddikim',
#  'bock',
#  'hilloing',
#  'paramorphosis',
#  'mayfair',
#  'thacking',
#  'neediest',
#  'antimagistratical',
#  'semicomatose',
#  'spitball',
#  'nonillusively',
#  'troking',
#  'caruncula',
#  'colchicum',
#  'handgravure',
#  'chemigraph',
#  'enteromegaly',
#  'thirstier',
#  'grayed',
#  'leafless',
#  'offscourings',
#  'pillhead',
#  'testicardinate',
#  'wasegua',
#  'noun',
#  'hildebrandslied',
#  'nonejective',
#  'pennyearth',
#  'platers',
#  'prodd',
#  'unacrimoniousness',
#  'archtempter',
#  'ecclesiastics',
#  'shoulderer',
#  'scutiferous',
#  'pithecomorphism',
#  'kingly',
#  'cannonballing',
#  'immember',
#  'ecbole',
#  'unstill',
#  'resiance',
#  'menage',
#  'squarely',
#  'reintrenched',
#  'pesterer',
#  'kirman',
#  'cucurb',
#  'leg',
#  'porterage',
#  'ruing',
#  'fasciation',
#  'gogmagog',
#  'turtleneck',
#  'massacrers',
#  'cosecant',
#  'introspectional',
#  'purred',
#  'fentanyl',
#  'unegotistical',
#  'rutaecarpine',
#  'calculably',
#  'pleasurably',
#  'grieffully',
#  'taxed',
#  'panchayet',
#  'fregatae',
#  'hymeniophore',
#  'thereben',
#  'mining',
#  'serval',
#  'freezing',
#  'dicrotous',
#  'exogyra',
#  'vanfoss',
#  'remuster',
#  'discomforter',
#  'khatri',
#  'sacraria',
#  'sabbatia',
#  'provokingness',
#  'microcard',
#  'ensorcels',
#  'clogmaker',
#  'cystoma',
#  'yomim',
#  'polytheize',
#  'vernaculous',
#  'civvies',
#  'oratresses',
#  'spoutless',
#  'appointments',
#  'microgranulitic',
#  'diverging',
#  'disciplinarily',
#  'falcate',
#  'dorpers',
#  'latten',
#  'mooley',
#  'gilour',
#  'wintrily',
#  'unrelentingness',
#  'actifier',
#  'cogonal',
#  'victual',
#  'squam',
#  'biotransformation',
#  'outact',
#  'flintily',
#  'sanativeness',
#  'ultraist',
#  'dracontites',
#  'hubble',
#  'insults',
#  'poebird',
#  'toys',
#  'smilacaceae',
#  'unsheaf',
#  'apophasis',
#  'poisonless',
#  'yirrs',
#  'untottering',
#  'fermentable',
#  'outwarbled',
#  'razored',
#  'predissatisfaction',
#  'pteropodium',
#  'disinherison',
#  'nondemocratic',
#  'unpractised',
#  'gravat',
#  'photomicrographer',
#  'burglarproofing',
#  'ghostship',
#  'velured',
#  'decolourizing',
#  'moorworts',
#  'unadaptedly',
#  'underlaundress',
#  'vidame',
#  'yah',
#  'faineancy',
#  'trochiscus',
#  'cyrtoceratite',
#  'scawd',
#  'sulpharseniate',
#  'lander',
#  'sassanian',
#  'intumesced',
#  'encaptivate',
#  'wheatstone',
#  'reincarnate',
#  'contraceptives',
#  'highfaluting',
#  'jarovizes',
#  'stridlins',
#  'ablastin',
#  'fuligula',
#  'defiled',
#  'horological',
#  'hapax',
#  'wareroom',
#  'melano',
#  'fagottino',
#  'superrefine',
#  'heterotelism',
#  'tilemaker',
#  'misiones',
#  'articled',
#  'petasos',
#  'budgers',
#  'rukbat',
#  'mesosternebra',
#  'breedling',
#  'todays',
#  'northwestern',
#  'chalkpit',
#  'heliozoic',
#  'misguesses',
#  'nitrifying',
#  'smacker',
#  'gyrotheca',
#  'winterage',
#  'smirked',
#  'leucocytopenic',
#  'aurae',
#  'patricio',
#  'undefiantly',
#  'newsreel',
#  'olds',
#  'cablets',
#  'claustrophobic',
#  'heydays',
#  'countrieman',
#  'theomachies',
#  'parrotlet',
#  'peripleuritis',
#  'maternology',
#  'tungs',
#  'menaceful',
#  'eusebian',
#  'caginesses',
#  'flytrap',
#  'curiouser',
#  'stichel',
#  'tetrachordon',
#  'omnividence',
#  'takin',
#  'squirrelly',
#  'tutor',
#  'anticrepuscular',
#  'giddiest',
#  'carbine',
#  'expressionistic',
#  'shaman',
#  'subworkman',
#  'bromouracil',
#  'zonoskeleton',
#  'noneducated',
#  'carian',
#  'fulgid',
#  'sulphocinnamic',
#  'swigging',
#  'transnational',
#  'glassblowing',
#  'unempt',
#  'gibbosely',
#  'glonoin',
#  'pyromantic',
#  'roc',
#  'coenosteal',
#  'cotterway',
#  'underbuy',
#  'heruli',
#  'bacchanalization',
#  'roominess',
#  'submatrices',
#  'scopiferous',
#  'nookeries',
#  'labyrinthodonta',
#  'vitiator',
#  'inquinated',
#  'weinschenkite',
#  'colloblast',
#  'bihalve',
#  'pseudoassertively',
#  'eelworms',
#  'chowse',
#  'mellon',
#  'hoggers',
#  'preinvent',
#  'trackwork',
#  'pickeering',
#  'hippometric',
#  'unfeignably',
#  'biosystematist',
#  'crazedly',
#  'nonintermittent',
#  'schismatize',
#  'ovivorous',
#  'stire',
#  'brutal',
#  'steadyingly',
#  'expeditation',
#  'mussurana',
#  'gambrel',
#  'precognitions',
#  'alcibiades',
#  'spathiform',
#  'rapscallions',
#  'roturiers',
#  'bard',
#  'yuch',
#  'muskroot',
#  'orotunds',
#  'polymers',
#  'telemetrography',
#  'titillate',
#  'clonicity',
#  'unstripped',
#  'lyricist',
#  'malcolm',
#  'ablative',
#  'pappescent',
#  'pennage',
#  'polygenesic',
#  'arrantness',
#  'spic',
#  'winceys',
#  'swarga',
#  'anthropomorphization',
#  'arion',
#  'granularly',
#  'mendigo',
#  'personship',
#  'interventions',
#  'hypogeum',
#  'precordia',
#  'sissu',
#  'wrinkly',
#  'mohairs',
#  'excommunicable',
#  'resignatary',
#  'tetragrammatonic',
#  'ergastic',
#  'outzany',
#  'benzoin',
#  'mammea',
#  'supplejack',
#  'circumnutating',
#  'disorderedness',
#  'cacicus',
#  'friller',
#  'tracheoscopy',
#  'courtling',
#  'dedd',
#  'corvee',
#  'metewand',
#  'spinula',
#  'typikons',
#  'prehydration',
#  'totality',
#  'symbasically',
#  'channelure',
#  'hypolydian',
#  'incoached',
#  'ecesises',
#  'charismatic',
#  'uncelestialized',
#  'hochhuth',
#  'seemlier',
#  'perseverant',
#  'prewarms',
#  'pectorally',
#  'ecyphellate',
#  'maturate',
#  'bonav',
#  'rhamnaceous',
#  'apholate',
#  'nav',
#  'pulmotracheal',
#  'unchasteness',
#  'bugle',
#  'underbitten',
#  'abl',
#  'alkanal',
#  'vascularize',
#  'mastocarcinoma',
#  'shirty',
#  'bandicoot',
#  'tenostosis',
#  'unfraudulent',
#  'inkhornize',
#  'refill',
#  'exequatur',
#  'deferrers',
#  'elianic',
#  'polydactylous',
#  'soarability',
#  'unteem',
#  'auspicating',
#  'conicality',
#  'postludium',
#  'holosiderite',
#  'consorts',
#  'ratchet',
#  'adherents',
#  'perigloea',
#  'lunacy',
#  'briefing',
#  'professionless',
#  'antitropal',
#  'morphinate',
#  'tarazed',
#  'indesert',
#  'traitorhood',
#  'tuberculoprotein',
#  'indonesian',
#  'motacillid',
#  'unsconced',
#  'enhalos',
#  'eggheaded',
#  'ramosity',
#  'eoiths',
#  'preearthquake',
#  'unstammeringly',
#  'lykewake',
#  'vacciniform',
#  'hangmanship',
#  'subtitled',
#  'automata',
#  'slivovitz',
#  'bashaw',
#  'faulds',
#  'broncho',
#  'grizzlier',
#  'marriage',
#  'anachronistic',
#  'sintu',
#  'sax',
#  'wots',
#  'hawaiian',
#  'gephyrean',
#  'irradicated',
#  'skeppund',
#  'swinebread',
#  'brabant',
#  'exothermous',
#  'institorian',
#  'overwithered',
#  'overidentifying',
#  'whitewood',
#  'disreputably',
#  'sermonism',
#  'invaded',
#  'stockado',
#  'programmers',
#  'disregardfulness',
#  'pointage',
#  'establishmentism',
#  'frawn',
#  'trailboard',
#  'buzzgloak',
#  'deprivable',
#  'leucobryum',
#  'inerring',
#  'subvitalised',
#  'salination',
#  'torula',
#  'postmortuary',
#  'abede',
#  'hemathermous',
#  'malaria',
#  'roughhousy',
#  'nondiffusibleness',
#  'underlap',
#  'nationalizing',
#  'undripping',
#  'stablelike',
#  'starmonger',
#  'serricornia',
#  'overtakers',
#  'approved',
#  'unquiescently',
#  'hypercalcuria',
#  'jugular',
#  'sugarberry',
#  'crepuscle',
#  'pseudoaristocratically',
#  'stepniece',
#  'thyreohyal',
#  'ophiuran',
#  'unchastened',
#  'hepatizing',
#  'signetwise',
#  'overattenuated',
#  'longanimities',
#  'overdevout',
#  'lubrication',
#  'paratheria',
#  'nemalion',
#  'plots',
#  'tumbrels',
#  'unloathly',
#  'oxozone',
#  'fawkener',
#  'allophonic',
#  'stomatoscope',
#  'caudatolenticular',
#  'populational',
#  'stratigraphical',
#  'mytilaceous',
#  'reexposition',
#  'wreathed',
#  'inequigranular',
#  'rumpuncheon',
#  'vadimony',
#  'disazo',
#  'enocyte',
#  'epichondrotic',
#  'crocky',
#  'unregretful',
#  'coralene',
#  'nonreasonable',
#  'erat',
#  'fawny',
#  'hernandiaceous',
#  'pewfellow',
#  'adenomyxosarcoma',
#  'penistone',
#  'photogalvanography',
#  'salubriously',
#  'birler',
#  'puntout',
#  'extradotal',
#  'fourberie',
#  'unspruced',
#  'univocability',
#  'ganzie',
#  'qualmyish',
#  'quinary',
#  'hydroglider',
#  'disuniform',
#  'manufacturers',
#  'ciderkin',
#  'disinclining',
#  'moyle',
#  'venturesome',
#  'outsold',
#  'arsenicked',
#  'celioelytrotomy',
#  'scutibranchian',
#  'inimicability',
#  'abp',
#  'heteroblastically',
#  'araneid',
#  'darks',
#  'breastpin',
#  'spiraling',
#  'epipedometry',
#  'spruit',
#  'reitbuck',
#  'voyagers',
#  'ecumenist',
#  'palistrophia',
#  'ignified',
#  'daintified',
#  'misapprehensible',
#  'woolward',
#  'paleoglaciology',
#  'scours',
#  'eldred',
#  'reptation',
#  'unposing',
#  'limpsey',
#  'rel',
#  'concyclic',
#  'regrasp',
#  'berrettas',
#  'palmesthesia',
#  'wasteboard',
#  'debatingly',
#  'commutuality',
#  'urbanist',
#  'gutlike',
#  'osphresiologic',
#  'narrowed',
#  'hologynies',
#  'pluckless',
#  'masticator',
#  'bylaw',
#  'dissipativity',
#  'gastrulae',
#  'guige',
#  'pronavy',
#  'smithite',
#  'britons',
#  'prefills',
#  'premiums',
#  'adherescence',
#  'holomorphy',
#  'troubadours',
#  'melebiose',
#  'nonlixiviated',
#  'unsordid',
#  'correlational',
#  'kamseen',
#  'unifiedly',
#  'unprofitableness',
#  'demesnes',
#  'sides',
#  'unrightfully',
#  'episcopise',
#  'frenchman',
#  'purificatory',
#  'sprauchle',
#  'mispick',
#  'pugarees',
#  'demagogism',
#  'spartled',
#  'exhalable',
#  'portamento',
#  'popshop',
#  'emendations',
#  'sirenia',
#  'canaanitic',
#  'vealer',
#  'unrefinedly',
#  'chared',
#  'fountainously',
#  'petalled',
#  'undergroundling',
#  'onehood',
#  'deva',
#  'selena',
#  'cryptography',
#  'unobstinately',
#  'gemutlich',
#  'wainer',
#  'cyathaspis',
#  'stubbier',
#  'nots',
#  'stockinette',
#  'resummonable',
#  'picrodendraceae',
#  'outmarriage',
#  'talcums',
#  'caracoa',
#  'weldless',
#  'gnatproof',
#  'tabashir',
#  'qadi',
#  'outdistrict',
#  'causewayman',
#  'annunciators',
#  'skeptics',
#  'unreproached',
#  'overplaced',
#  'recognizance',
#  'gibbeting',
#  'unloosing',
#  'petroglyphic',
#  'zestfully',
#  'superinduce',
#  'feministic',
#  'chassignite',
#  'unpriced',
#  'attendress',
#  'jant',
#  'monbuttu',
#  'narrated',
#  'rostellum',
#  'proconstitutionalism',
#  'neurogram',
#  'vacuolation',
#  'pennatulacean',
#  'metallorganic',
#  'eyases',
#  'prograde',
#  'saltman',
#  'muciform',
#  'holomorphosis',
#  'unmoralize',
#  'bamboo',
#  'gers',
#  'superlogicality',
#  'isocolon',
#  'creches',
#  'diaclasite',
#  'cassioberry',
#  'amala',
#  'killweed',
#  'zonary',
#  'intertwistingly',
#  'pseudostigma',
#  'apexes',
#  'nonvacuum',
#  'microelectrophoretically',
#  'megacolon',
#  'alveolate',
#  'hyperconfidence',
#  'inelasticity',
#  'toxicaemia',
#  'subbureaus',
#  'epitomical',
#  'stonewalled',
#  'coralberry',
#  'auriscope',
#  'untouching',
#  'tinkerly',
#  'branles',
#  'decelerate',
#  'sphaerophorus',
#  'outtasking',
#  'waterproof',
#  'lennilite',
#  'blarny',
#  'formulators',
#  'romancealist',
#  'implementiferous',
#  'esterlin',
#  'unameliorable',
#  'craftmanship',
#  'diploptera',
#  'prognosing',
#  'ultrahot',
#  'pyrophosphorous',
#  'celadonite',
#  'ceremonialize',
#  'chronometrical',
#  'rainful',
#  'hemifacial',
#  'leadwort',
#  'gorkun',
#  'monographing',
#  'pterylological',
#  'capillaceous',
#  'rhineurynter',
#  'unrated',
#  'idyllicism',
#  'unfrugality',
#  'barosma',
#  'nippling',
#  'syre',
#  'declinate',
#  'studiedly',
#  'hectostere',
#  'assumpsit',
#  'nonobligatorily',
#  ...]

# %%
len(wordlist)
# Out:
# 370099

# %%
def wordhash(hashID, shortening = 10):
    random.seed(hashID)
    nWords = math.ceil(len(hashID) * math.log(260, len(wordlist)) / shortening)
    wordhashlist = random.sample(wordlist, nWords)
    wordhashstr = '_'.join(wordhashlist).replace('__', '_')
    return wordhashstr

# %%
hashID = '0dd5d59ee25ed58f1b27fd29858ffde7'

# %%
wordhash(hashID)
# Out:
# 'anapestic_estopped'

# %%
len(wordlist)**2
# Out:
# 136973269801
